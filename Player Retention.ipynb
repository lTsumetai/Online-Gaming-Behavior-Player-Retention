# %% [markdown]
# ### Section 1. problem statement and dataset description

# %% [markdown]
# Defining the Problem Statements
#
# Using SMART framework:
#
# 1. **Specific**: enhancing player loyalty, achiving stable player count and retention on an online gaming
#
# 2. **Measurable**: stable player count.
#
# 3. **Achievable**: Improving player experience by studying how, when, and what players play.
#
# 4. **Relevant**: Stable player count can leads to healthy playerbase.
#
# 5. **Time-Bound**: achive within next season ( 6 months ).
#
# `Problem statement`:
# main goal is to achive stable player count and improving player experience, within the next season 6 months prior so the player base would be much healthier. stable player counts can be studied by how,when, and what players play.

# %% [markdown]
# ### Section 2. Data Loading

# %% [markdown]
# #### Lists of libraries

# %%
import pandas as pd
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %% [markdown]
# #### Dataset kaggle reading

# %%
Online_gaming_df = pd.read_csv("online_gaming_behavior_dataset.csv")
Online_gaming_df
# Out:
#        PlayerID  Age  Gender Location   GameGenre  PlayTimeHours  \
# 0          9000   43    Male    Other    Strategy      16.271119
# 1          9001   29  Female      USA    Strategy       5.525961
# 2          9002   22  Female      USA      Sports       8.223755
# 3          9003   35    Male      USA      Action       5.265351
# 4          9004   33    Male   Europe      Action      15.531945
# ...         ...  ...     ...      ...         ...            ...
# 40029     49029   32    Male      USA    Strategy      20.619662
# 40030     49030   44  Female    Other  Simulation      13.539280
# 40031     49031   15  Female      USA         RPG       0.240057
# 40032     49032   34    Male      USA      Sports      14.017818
# 40033     49033   19    Male      USA      Sports      10.083804
#
#        InGamePurchases GameDifficulty  SessionsPerWeek  \
# 0                    0         Medium                6
# 1                    0         Medium                5
# ...

# %% [markdown]
# #### Data Structures. understanding the data by getting the rows and columns
#  From the outputs we can gather that, there are a total of 40034 rows and 13 columns.

# %%
Online_gaming_df.shape
# Out:
# (40034, 13)

# %%
Online_gaming_df.columns.to_list()
# Out:
# ['PlayerID',
#  'Age',
#  'Gender',
#  'Location',
#  'GameGenre',
#  'PlayTimeHours',
#  'InGamePurchases',
#  'GameDifficulty',
#  'SessionsPerWeek',
#  'AvgSessionDurationMinutes',
#  'PlayerLevel',
#  'AchievementsUnlocked',
#  'EngagementLevel']

# %% [markdown]
# #### Checking Data Types

# %%
Online_gaming_df.dtypes
# Out:
# PlayerID                       int64
# Age                            int64
# Gender                        object
# Location                      object
# GameGenre                     object
# PlayTimeHours                float64
# InGamePurchases                int64
# GameDifficulty                object
# SessionsPerWeek                int64
# AvgSessionDurationMinutes      int64
# PlayerLevel                    int64
# AchievementsUnlocked           int64
# EngagementLevel               object
# dtype: object

# %%
Online_gaming_df.head(10)
# Out:
#    PlayerID  Age  Gender Location   GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other    Strategy      16.271119                0
# 1      9001   29  Female      USA    Strategy       5.525961                0
# 2      9002   22  Female      USA      Sports       8.223755                0
# 3      9003   35    Male      USA      Action       5.265351                1
# 4      9004   33    Male   Europe      Action      15.531945                0
# 5      9005   37    Male   Europe         RPG      20.561855                0
# 6      9006   25    Male      USA      Action       9.752716                0
# 7      9007   25  Female     Asia         RPG       4.401729                0
# 8      9008   38  Female   Europe  Simulation      18.152733                0
# 9      9009   38  Female    Other      Sports      23.942772                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# ...

# %% [markdown]
# #### Statistics summary. min, max, mean, distributions for numeric coloumns

# %%
Online_gaming_df.describe()
# Out:
#            PlayerID           Age  PlayTimeHours  InGamePurchases  \
# count  40034.000000  40034.000000   40034.000000     40034.000000
# mean   29016.500000     31.992531      12.024365         0.200854
# std    11556.964675     10.043227       6.914638         0.400644
# min     9000.000000     15.000000       0.000115         0.000000
# 25%    19008.250000     23.000000       6.067501         0.000000
# 50%    29016.500000     32.000000      12.008002         0.000000
# 75%    39024.750000     41.000000      17.963831         0.000000
# max    49033.000000     49.000000      23.999592         1.000000
#
#        SessionsPerWeek  AvgSessionDurationMinutes   PlayerLevel  \
# count     40034.000000               40034.000000  40034.000000
# mean          9.471774                  94.792252     49.655568
# std           5.763667                  49.011375     28.588379
# min           0.000000                  10.000000      1.000000
# ...

# %% [markdown]
# #### Missing Values

# %%
Online_gaming_df.isnull().sum()
# Out:
# PlayerID                     0
# Age                          0
# Gender                       0
# Location                     0
# GameGenre                    0
# PlayTimeHours                0
# InGamePurchases              0
# GameDifficulty               0
# SessionsPerWeek              0
# AvgSessionDurationMinutes    0
# PlayerLevel                  0
# AchievementsUnlocked         0
# EngagementLevel              0
# dtype: int64

# %% [markdown]
# #### Duplicates

# %%
Online_gaming_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Unique Value Counts

# %%
Online_gaming_df.nunique()
# Out:
# PlayerID                     40034
# Age                             35
# Gender                           2
# Location                         4
# GameGenre                        5
# PlayTimeHours                40034
# InGamePurchases                  2
# GameDifficulty                   3
# SessionsPerWeek                 20
# AvgSessionDurationMinutes      170
# PlayerLevel                     99
# AchievementsUnlocked            50
# EngagementLevel                  3
# dtype: int64

# %% [markdown]
# ### Section 3. Data Cleaning
# Since the dataset doesn't have any
# - duplicates
# - missing values
#
# on data exploration. we can change object dtype to strings, so it wont be ambiguous

# %%
obj_change = ['Gender', 'Location', 'GameGenre', 'GameDifficulty', 'EngagementLevel']
Online_gaming_df[obj_change] = Online_gaming_df[obj_change].astype('string')

# %%
Online_gaming_df.dtypes
# Out:
# PlayerID                              int64
# Age                                   int64
# Gender                       string[python]
# Location                     string[python]
# GameGenre                    string[python]
# PlayTimeHours                       float64
# InGamePurchases                       int64
# GameDifficulty               string[python]
# SessionsPerWeek                       int64
# AvgSessionDurationMinutes             int64
# PlayerLevel                           int64
# AchievementsUnlocked                  int64
# EngagementLevel              string[python]
# dtype: object

# %% [markdown]
# ### Section 4. Data Analysis and Exploratory Data Analysis (EDA) for SMART framework and the main problem of case study

# %% [markdown]
# ##### What factors influence player engagement behavior?
# To answer this question, we analyze whether there is a significant difference in player activity between different engagement groups.
#
# in particular, we want to understand :
# > Do highly engaged players spend more time playing compared to low-engagement players?

# %% [markdown]
# We can gather that there is a variable called
# > EngagementLevel: Indicates the level of player engagement categorized as 'High', 'Medium', or 'Low'.
#
# we can identify what it means and how we will use this variable to answer our factors

# %%
# Group by EngagementLevel and calculate average sessions
engagement_summary = (
    Online_gaming_df.groupby('EngagementLevel')['SessionsPerWeek']
      .mean()
      .reset_index()
      .rename(columns={'SessionsPerWeek': 'AvgSessionsPerWeek'})
      .sort_values(by='AvgSessionsPerWeek')
)

engagement_summary
# Out:
#   EngagementLevel  AvgSessionsPerWeek
# 1             Low            4.530511
# 2          Medium            9.553267
# 0            High           14.254547

# %%
# Bar chart: visualiazing average sessions per week by engagement level
plt.figure(figsize=(10, 6))
plt.bar(engagement_summary['EngagementLevel'], engagement_summary['AvgSessionsPerWeek'], color=['skyblue', 'salmon', 'lightgreen'])
plt.title('Average Sessions Per Week by Engagement Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# The results show that the higher engagement level players have, the more sessions they have per week.
#
# From the results we can confirm that EngagementLevel Variable is a summary label that's represents player activity.

# %% [markdown]
# since EngagementLevel Confirms a summary label, we can use it to perform Statistical Significance with the current hypothesis :
#
# >$H_0$: There is no difference in mean playtime between low and high engagement players.
#
# >$H_1$: There is a significant difference in mean playtime between low and high engagement players.
#
# We will use confidence level of 95%. which means p-value = 0.05

# %%
# grouping/filtering data using labels based on EngagementLevel
low  = Online_gaming_df[Online_gaming_df['EngagementLevel'] == 'Low']['PlayTimeHours']
high = Online_gaming_df[Online_gaming_df['EngagementLevel'] == 'High']['PlayTimeHours']

# %%
print("Low Engagement PlayTime:")
print(low)
print("\nHigh Engagement PlayTime:")
print(high)
# Out:
# Low Engagement PlayTime:
# 5        20.561855
# 6         9.752716
# 13        8.701959
# 14       17.975200
# 17       17.272113
#            ...
# 40018     5.950284
# 40022     9.085086
# 40023     2.529218
# 40027     1.273467
# 40028     1.020489
# Name: PlayTimeHours, Length: 10324, dtype: float64
#
# High Engagement PlayTime:
# 2         8.223755
# 9        23.942772
# 10        4.829916
# 11        5.535981
# 12       18.776234
#            ...
# 40013     9.077397
# 40020    10.687862
# 40026    19.825140
# 40030    13.539280
# 40031     0.240057
# Name: PlayTimeHours, Length: 10336, dtype: float64

# %%
# Using Two-Sample T-test
t_stat, p_value = stats.ttest_ind(low, high)

print("T-statistic:", t_stat)
print("P-value:", p_value)
# Out:
# T-statistic: 0.3715643967745735
# P-value: 0.710221012114041

# %%
alpha = 0.05

print("Mean Playtime (Low):", low.mean())
print("Mean Playtime (High):", high.mean())
print()

if p_value < alpha:
    print("Reject H0 : There is a significant difference in playtime.")
else:
    print("Fail to reject H0 : No significant difference detected.")
# Out:
# Mean Playtime (Low): 12.10491461074908
# Mean Playtime (High): 12.069238073121078
#
# Fail to reject H0 : No significant difference detected.

# %%
# Bar chart: Mean PlayTimeHours by Engagement Level
means = [low.mean(), high.mean()]
labels = ['Low Engagement', 'High Engagement']
colors = ['#f28b82', '#81c995']

fig, ax = plt.subplots(figsize=(7, 5))
bars = ax.bar(labels, means, color=colors, edgecolor='white', width=0.5)
ax.bar_label(bars, fmt='%.2f', padding=5, fontsize=11)
ax.set_title('Mean PlayTimeHours: Low vs High Engagement', fontsize=13, fontweight='bold')
ax.set_ylabel('Mean Play Time (Hours)')
ax.set_ylim(0, max(means) * 1.15)

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on Two Sample T-test. the result shows that the average playtime for low engagement players (12.10 hours) and high engagement players (12.07 hours) is nearly identical. meaning that there is no significant difference in playtime between low and high engagement players.

# %% [markdown]
# ##### What do players play?

# %% [markdown]
# To understand *what* players play, we examine the distribution of game genres across engagement levels.
# This tells us which genres are associated with higher or lower engagement, directly informing what game experiences to invest in.

# %% [markdown]
# Hence, we want to know :
# > Do certain game genres attract more highly engaged players?

# %% [markdown]
# therefore, we can analyze if there is a significant correlation between GameGenre and EngagementLevel. for this problem, we will use a **Chi-Square Test of Independence** since both variables are categorical.

# %% [markdown]
# we can use to perforce statistical significance with the current hyphotehsis
#
# > $H_0$: `GameGenre` and `EngagementLevel` are independent (no association).
# > $H_1$: `GameGenre` and `EngagementLevel` are associated.
#
# and as usual, the confidence level will be: 95% (α = 0.05)

# %%
# Cross-tabulation: GameGenre vs EngagementLevel
genre_engagement = pd.crosstab(Online_gaming_df['GameGenre'], Online_gaming_df['EngagementLevel'])
print('Contingency Table (GameGenre vs EngagementLevel):')
print(genre_engagement)
# Out:
# Contingency Table (GameGenre vs EngagementLevel):
# EngagementLevel  High   Low  Medium
# GameGenre
# Action           2064  2059    3916
# RPG              1988  2097    3867
# Simulation       2104  2088    3791
# Sports           2083  2074    3891
# Strategy         2097  2006    3909

# %%
# Chi-Square Test of Independence
chi2, p_chi, dof, expected = stats.chi2_contingency(genre_engagement)

print(f'Chi-Square Statistic : {chi2:.4f}')
print(f'P-value              : {p_chi:.4f}')
print(f'Degrees of Freedom   : {dof}')
print()
if p_chi < 0.05:
    print('Reject H0: GameGenre and EngagementLevel are significantly associated.')
else:
    print('Fail to reject H0: No significant association between GameGenre and EngagementLevel.')
# Out:
# Chi-Square Statistic : 8.6112
# P-value              : 0.3761
# Degrees of Freedom   : 8
#
# Fail to reject H0: No significant association between GameGenre and EngagementLevel.

# %%
# Visualize: Genre distribution across Engagement Levels (stacked bar)
genre_pct = genre_engagement.div(genre_engagement.sum(axis=1), axis=0) * 100

fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Count plot
genre_engagement.plot(kind='bar', ax=axes[0], colormap='Set2', edgecolor='white')
axes[0].set_title('GameGenre vs EngagementLevel (Count)', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Game Genre')
axes[0].set_ylabel('Player Count')
axes[0].tick_params(axis='x', rotation=30)
axes[0].legend(title='Engagement Level')

# Percentage plot
genre_pct.plot(kind='bar', stacked=True, ax=axes[1], colormap='Set2', edgecolor='white')
axes[1].set_title('GameGenre vs EngagementLevel (% Share)', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Game Genre')
axes[1].set_ylabel('Percentage (%)')
axes[1].tick_params(axis='x', rotation=30)
axes[1].legend(title='Engagement Level', loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### When Do players play ?

# %% [markdown]
# To understand *when* players play, we examine player sessions per week. which then can tells us how engaged players are and how often or for longer each session

# %% [markdown]
# Hence, we want to know :
# > Do highly engaged players play more *often* or for *longer* per session?

# %% [markdown]
# therefore, we can analyze if there is players with high engagement levels plays more ofter per session with Measures of Dispresion. with Measures of Dispersion we can compare the average between two groups. and to show how spread out the data is.

# %%
metrics = ['SessionsPerWeek', 'AvgSessionDurationMinutes']

for metric in metrics:
    print(f'=== {metric} ===')
    for level in ['Low', 'Medium', 'High']:
        group = Online_gaming_df[Online_gaming_df['EngagementLevel'] == level][metric]
        q1, q3 = group.quantile(0.25), group.quantile(0.75)
        print(f'  {level} Engagement:')
        print(f'    Mean   : {group.mean():.2f}')
        print(f'    Std Dev: {group.std():.2f}')
        print(f'    Range  : {group.max() - group.min():.2f}')
        print(f'    IQR    : {q3 - q1:.2f}')
    print()
# Out:
# === SessionsPerWeek ===
#   Low Engagement:
#     Mean   : 4.53
#     Std Dev: 4.86
#     Range  : 19.00
#     IQR    : 6.00
#   Medium Engagement:
#     Mean   : 9.55
#     Std Dev: 4.76
#     Range  : 19.00
#     IQR    : 7.00
#   High Engagement:
#     Mean   : 14.25
#     Std Dev: 3.91
#     Range  : 19.00
#     IQR    : 5.00
#
# === AvgSessionDurationMinutes ===
#   Low Engagement:
#     Mean   : 66.88
#     Std Dev: 48.59
#     Range  : 169.00
#     IQR    : 78.00
#   Medium Engagement:
#     Mean   : 89.86
#     Std Dev: 43.72
#     Range  : 169.00
#     IQR    : 70.00
#   High Engagement:
#     Mean   : 131.92
#     Std Dev: 34.07
#     Range  : 169.00
#     IQR    : 48.00

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
engagement_order = ['Low', 'Medium', 'High']
colors = ['#f28b82', '#aecbfa', '#81c995']

for ax, metric, label in zip(
    axes,
    ['SessionsPerWeek', 'AvgSessionDurationMinutes'],
    ['Sessions Per Week', 'Avg Session Duration (Minutes)']
):
    data_by_level = [Online_gaming_df[Online_gaming_df['EngagementLevel'] == lvl][metric]
                     for lvl in engagement_order]
    bp = ax.boxplot(data_by_level, labels=engagement_order, patch_artist=True, notch=True)
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
    ax.set_title(f'{label} by Engagement Level\n(Dispersion View)', fontsize=12, fontweight='bold')
    ax.set_xlabel('Engagement Level')
    ax.set_ylabel(label)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Fauzi Maulana\AppData\Local\Temp\ipykernel_7424\103333383.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_by_level, labels=engagement_order, patch_artist=True, notch=True)
# C:\Users\Fauzi Maulana\AppData\Local\Temp\ipykernel_7424\103333383.py:12: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax.boxplot(data_by_level, labels=engagement_order, patch_artist=True, notch=True)

# %% [markdown]
# Based On.........

# %% [markdown]
# ##### Does Player progression relate to engagement ?

# %% [markdown]
# we wether analyze player progression is related to enagement to determine what factors that can improve player retention.

# %% [markdown]
# Here we will use Spearman correlation to measure wether the two variables move together. we can gather from the previous result that `engagement level` is ordinal ( it has an order). hence spearman correlation will be applied

# %% [markdown]
# To use correlation, we need to turn `EngagementLevel` into nummbers :
# | EngagementLevel | Value |
# |---|---|
# | Low | 0 |
# | Medium| 1 |
# | High | 2 |
#
# This keeps the order intact (Low is still "less than" High) without inventing fake distances between them.

# %%
# Convert : Low=0, Medium=1, High=2 — preserves the ranking order
engagement_map = {'Low': 0, 'Medium': 1, 'High': 2}
engagement_numeric = Online_gaming_df['EngagementLevel'].map(engagement_map)

# %%
for col in ['PlayerLevel', 'AchievementsUnlocked']:
    r, p = stats.spearmanr(Online_gaming_df[col], engagement_numeric)
    print(f'=== {col} ===')
    print(f'  Spearman r : {r:.4f}')
    print(f'  P-value    : {p:.4f}')
    if abs(r) >= 0.7:
        strength = 'Strong'
    elif abs(r) >= 0.4:
        strength = 'Moderate'
    else:
        strength = 'Weak'
    direction = 'positive' if r > 0 else 'negative'
    print(f'  Interpretation: {strength} {direction} correlation')
    print()
# Out:
# === PlayerLevel ===
#   Spearman r : 0.0593
#   P-value    : 0.0000
#   Interpretation: Weak positive correlation
#
# === AchievementsUnlocked ===
#   Spearman r : 0.0606
#   P-value    : 0.0000
#   Interpretation: Weak positive correlation

# %% [markdown]
# This means.....

# %% [markdown]
# ### Section 5. Conclusion
